# %%
import numpy as np 
import pandas as pd 
import os 
import random 
from tqdm import tqdm 
import torch 
import torch.nn as nn 
import json 
import matplotlib.pyplot as plt 
from transformers import AutoTokenizer, AlbertTokenizer, AutoModelForSequenceClassification
import pickle
import pandas_ta as ta # needed for processing chart data 
from random import randrange # needed for random agent
from sklearn.utils.class_weight import compute_class_weight
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor 
from sklearn.metrics import f1_score  
import ccxt

# %% [markdown]
# # json -> csv 변환

# %%
with open("BTC_USDT-4h_interval.json") as f: 
    d = json.load(f) 
    
chart_df = pd.DataFrame(d) 
chart_df = chart_df.rename(columns={0:"timestamp",
                                    1:"open",
                                    2:"high",
                                    3:"low", 
                                    4:"close",
                                    5:"volume"}) 

def process(df):
    binance = ccxt.binance() 
    dates = df['timestamp'].values 
    timestamp = [] 
    for i in range(len(dates)):
        date_string = binance.iso8601(int(dates[i])) 
        date_string = date_string[:10] + " " + date_string[11:-5] 
        timestamp.append(date_string) 
    df['datetime'] = timestamp 
    df = df.drop(columns={'timestamp'}) 
    return df

chart_df = process(chart_df) 

hours, days, months, years = [],[],[],[] 

for dt in tqdm(chart_df['datetime']):
    dtobj = pd.to_datetime(dt) 
    hour = dtobj.hour 
    day = dtobj.day 
    month = dtobj.month 
    year = dtobj.year 
    hours.append(hour)
    days.append(day) 
    months.append(month)
    years.append(year) 
    
chart_df['years'], chart_df['months'], chart_df['days'], chart_df['hours'] = years, months, days, hours
    
high_change, low_change = [], [] 
close = chart_df['close'].values 
high = chart_df['high'].values 
low = chart_df['low'].values 
for i in range(close.shape[0]-1):
    high_delta = (high[i+1] - close[i]) / close[i] 
    low_delta = (low[i+1] - close[i]) / close[i]
    high_change.append(high_delta) 
    low_change.append(low_delta)
high_change.append(None) 
low_change.append(None)

chart_df['high_delta'] = high_change
chart_df['low_delta'] = low_change 

chart_df.dropna(inplace=True) 

chart_df
# Out:
# 100%|██████████| 10560/10560 [00:01<00:00, 7092.40it/s]
#            open      high       low     close        volume  \
# 0       4261.48   4349.99   4261.32   4349.99     82.088865
# 1       4333.32   4485.39   4333.32   4427.30     63.619882
# 2       4436.06   4485.39   4333.42   4352.34    174.562001
# 3       4352.33   4354.84   4200.74   4325.23    225.109716
# 4       4307.56   4369.69   4258.56   4285.08    249.769913
# ...         ...       ...       ...       ...           ...
# 10554  22485.27  22796.71  20846.00  22127.91  64139.981750
# 10555  22127.92  23362.88  21763.71  22877.52  43892.535610
# 10556  22877.52  22979.96  21725.22  21994.56  22494.024070
# 10557  21994.56  22800.00  21811.01  22680.38  29165.257260
# 10558  22680.38  22777.07  22126.40  22196.28  11465.173320
#
#                   datetime  years  months  days  hours  high_delta  low_delta
# 0      2017-08-17 04:00:00   2017       8    17      4    0.031127  -0.003832
# 1      2017-08-17 08:00:00   2017       8    17      8    0.013121  -0.021205
# 2      2017-08-17 12:00:00   2017       8    17     12    0.000574  -0.034832
# 3      2017-08-17 16:00:00   2017       8    17     16    0.010279  -0.015414
# 4      2017-08-17 20:00:00   2017       8    17     20    0.012961  -0.035115
# ...                    ...    ...     ...   ...    ...         ...        ...
# 10554  2022-06-14 00:00:00   2022       6    14      0    0.055811  -0.016459
# 10555  2022-06-14 04:00:00   2022       6    14      4    0.004478  -0.050368
# 10556  2022-06-14 08:00:00   2022       6    14      8    0.036620  -0.008345
# 10557  2022-06-14 12:00:00   2022       6    14     12    0.004263  -0.024426
# 10558  2022-06-14 16:00:00   2022       6    14     16    0.006655  -0.037767
#
# [10559 rows x 12 columns]

# %% [markdown]
# # Feature Engineering

# %%
chart_df.set_index(pd.DatetimeIndex(chart_df['datetime']), inplace=True) 

chart_df['ebsw'] = chart_df.ta.ebsw(lookahead=False) 
chart_df['cmf'] = chart_df.ta.cmf(lookahead=False) 
chart_df['rsi/100'] = chart_df.ta.rsi(lookahead=False) / 100 
chart_df['vwap'] = chart_df.ta.vwap(lookahead=False) 
chart_df['high/low'] = chart_df['high'] / chart_df['low'] 
chart_df['close/open'] = chart_df['close'] / chart_df['open'] 
chart_df['high/open'] = chart_df['high'] / chart_df['open'] 
chart_df['low/open'] = chart_df['low'] / chart_df['open'] 

for i in tqdm(range(1, 4)): 
    for col in ['open', 'high', 'low', 'close', 'volume', 'vwap']:
        val = chart_df[col].values 
        val_ret = [None for _ in range(i)] 
        for j in range(i, len(val)): 
            if val[j-i] == 0:
                ret = 1 
            else:
                ret = val[j] / val[j-i] 
            val_ret.append(ret) 
        chart_df['{}_change_{}'.format(col, i)] = val_ret 
            
    

chart_df.dropna(inplace=True) 
chart_df.drop(columns={'datetime', 'open', 'high', 'low', 'close', 'volume', 'vwap'}, inplace=True)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 13.38it/s]

# %%
chart_df.head(2)
# Out:
#                      years  months  days  hours  high_delta  low_delta  \
# datetime
# 2017-08-23 16:00:00   2017       8    23     16    0.014957  -0.011481
# 2017-08-23 20:00:00   2017       8    23     20    0.022008  -0.007049
#
#                         ebsw       cmf   rsi/100  high/low  ...  low_change_2  \
# datetime                                                    ...
# 2017-08-23 16:00:00  0.00000  0.121501  0.514396  1.038033  ...      1.011464
# 2017-08-23 20:00:00  0.57735  0.097590  0.512374  1.026746  ...      0.980521
#
#                      close_change_2  volume_change_2  vwap_change_2  \
# datetime
# 2017-08-23 16:00:00        0.971468         1.293382       1.009008
# 2017-08-23 20:00:00        0.980215         0.642973       0.999909
#
#                      open_change_3  high_change_3  low_change_3  \
# datetime
# 2017-08-23 16:00:00       1.034863       1.034916      1.016898
# 2017-08-23 20:00:00       1.013438       0.984992      1.003155
#
#                      close_change_3  volume_change_3  vwap_change_3
# datetime
# 2017-08-23 16:00:00        1.010354         1.231233       1.016728
# 2017-08-23 20:00:00        0.970746         1.130291       1.008057
#
# [2 rows x 31 columns]

# %% [markdown]
# # Train High Model

# %%
# train/validation/test split 
train_size = int(chart_df.shape[0] * 0.8) 
train_df = chart_df.iloc[:train_size,:] 

val_size = int(chart_df.shape[0] * 0.1) 
val_df = chart_df.iloc[train_size:train_size+val_size,:]  

test_df = chart_df.iloc[train_size+val_size:, :]

# %%
input_columns = [] 
for col in train_df.columns:
    if col != 'low_delta' and col != 'years': 
        input_columns.append(col) 
        
X_train = train_df[input_columns].values 
Y_train = train_df['high_delta'].values 
Y_train = Y_train.reshape((-1,1))

X_val = val_df[input_columns].values
Y_val = val_df['high_delta'].values 
Y_val = Y_val.reshape((-1,1))

X_test = test_df[input_columns].values 
Y_test = test_df['high_delta'].values  
Y_test = Y_test.reshape((-1,1))

# %%
reg_high = TabNetRegressor() 

reg_high.fit(X_train, Y_train, 
             eval_set=[(X_val, Y_val)], 
             max_epochs=100, 
             patience=100)
# Out:
# Device used : cuda
# epoch 0  | loss: 0.36774 | val_0_mse: 0.41214 |  0:00:00s
# epoch 1  | loss: 0.04833 | val_0_mse: 0.00701 |  0:00:01s
# epoch 2  | loss: 0.01159 | val_0_mse: 0.00293 |  0:00:02s
# epoch 3  | loss: 0.00412 | val_0_mse: 0.00066 |  0:00:03s
# epoch 4  | loss: 0.00202 | val_0_mse: 0.00028 |  0:00:03s
# epoch 5  | loss: 0.00162 | val_0_mse: 0.00016 |  0:00:04s
# epoch 6  | loss: 0.00139 | val_0_mse: 0.00012 |  0:00:05s
# epoch 7  | loss: 0.00129 | val_0_mse: 0.00013 |  0:00:06s
# epoch 8  | loss: 0.00123 | val_0_mse: 0.00013 |  0:00:06s
# epoch 9  | loss: 0.0012  | val_0_mse: 0.00014 |  0:00:07s
# epoch 10 | loss: 0.00117 | val_0_mse: 0.00013 |  0:00:08s
# epoch 11 | loss: 0.00113 | val_0_mse: 0.00012 |  0:00:08s
# epoch 12 | loss: 0.0011  | val_0_mse: 0.00012 |  0:00:09s
# epoch 13 | loss: 0.00107 | val_0_mse: 0.00012 |  0:00:10s
# epoch 14 | loss: 0.00104 | val_0_mse: 0.00013 |  0:00:10s
# epoch 15 | loss: 0.001   | val_0_mse: 0.00012 |  0:00:11s
# epoch 16 | loss: 0.00097 | val_0_mse: 0.00012 |  0:00:12s
# epoch 17 | loss: 0.00094 | val_0_mse: 0.00013 |  0:00:12s
# epoch 18 | loss: 0.00094 | val_0_mse: 0.00012 |  0:00:13s
# epoch 19 | loss: 0.00091 | val_0_mse: 0.00014 |  0:00:14s
# epoch 20 | loss: 0.00089 | val_0_mse: 0.00012 |  0:00:15s
# epoch 21 | loss: 0.00087 | val_0_mse: 0.00012 |  0:00:15s
# epoch 22 | loss: 0.00086 | val_0_mse: 0.00012 |  0:00:16s
# epoch 23 | loss: 0.00088 | val_0_mse: 0.00012 |  0:00:17s
# epoch 24 | loss: 0.00084 | val_0_mse: 0.00013 |  0:00:17s
# epoch 25 | loss: 0.00082 | val_0_mse: 0.00012 |  0:00:18s
# epoch 26 | loss: 0.00081 | val_0_mse: 0.00013 |  0:00:19s
# epoch 27 | loss: 0.00079 | val_0_mse: 0.00012 |  0:00:19s
# epoch 28 | loss: 0.00079 | val_0_mse: 0.00012 |  0:00:20s
# epoch 29 | loss: 0.00077 | val_0_mse: 0.00012 |  0:00:21s
# epoch 30 | loss: 0.00077 | val_0_mse: 0.00014 |  0:00:21s
# epoch 31 | loss: 0.00076 | val_0_mse: 0.00012 |  0:00:22s
# epoch 32 | loss: 0.00075 | val_0_mse: 0.00012 |  0:00:23s
# epoch 33 | loss: 0.00075 | val_0_mse: 0.00012 |  0:00:23s
# epoch 34 | loss: 0.00074 | val_0_mse: 0.00012 |  0:00:24s
# epoch 35 | loss: 0.00073 | val_0_mse: 0.00012 |  0:00:25s
# epoch 36 | loss: 0.00073 | val_0_mse: 0.00012 |  0:00:25s
# epoch 37 | loss: 0.00073 | val_0_mse: 0.00012 |  0:00:26s
# epoch 38 | loss: 0.00072 | val_0_mse: 0.00011 |  0:00:27s
# epoch 39 | loss: 0.00072 | val_0_mse: 0.00014 |  0:00:27s
# epoch 40 | loss: 0.00073 | val_0_mse: 0.00012 |  0:00:28s
# epoch 41 | loss: 0.00071 | val_0_mse: 0.00011 |  0:00:29s
# epoch 42 | loss: 0.00072 | val_0_mse: 0.00012 |  0:00:29s
# epoch 43 | loss: 0.00071 | val_0_mse: 0.00012 |  0:00:30s
# epoch 44 | loss: 0.0007  | val_0_mse: 0.00011 |  0:00:31s
# epoch 45 | loss: 0.00069 | val_0_mse: 0.00012 |  0:00:31s
# epoch 46 | loss: 0.00069 | val_0_mse: 0.00011 |  0:00:32s
# epoch 47 | loss: 0.0007  | val_0_mse: 0.00014 |  0:00:33s
# epoch 48 | loss: 0.00068 | val_0_mse: 0.00011 |  0:00:34s
# epoch 49 | loss: 0.00068 | val_0_mse: 0.00011 |  0:00:34s
# epoch 50 | loss: 0.00067 | val_0_mse: 0.00011 |  0:00:35s
# epoch 51 | loss: 0.00068 | val_0_mse: 0.00012 |  0:00:36s
# epoch 52 | loss: 0.00067 | val_0_mse: 0.00011 |  0:00:36s
# epoch 53 | loss: 0.00066 | val_0_mse: 0.00012 |  0:00:37s
# epoch 54 | loss: 0.00066 | val_0_mse: 0.00011 |  0:00:38s
# epoch 55 | loss: 0.00067 | val_0_mse: 0.00011 |  0:00:38s
# epoch 56 | loss: 0.00066 | val_0_mse: 0.00011 |  0:00:39s
# epoch 57 | loss: 0.00066 | val_0_mse: 0.00011 |  0:00:40s
# epoch 58 | loss: 0.00065 | val_0_mse: 0.00011 |  0:00:40s
# epoch 59 | loss: 0.00065 | val_0_mse: 0.00011 |  0:00:41s
# epoch 60 | loss: 0.00064 | val_0_mse: 0.00011 |  0:00:41s
# epoch 61 | loss: 0.00064 | val_0_mse: 0.00011 |  0:00:42s
# epoch 62 | loss: 0.00063 | val_0_mse: 0.00011 |  0:00:43s
# epoch 63 | loss: 0.00063 | val_0_mse: 0.00011 |  0:00:43s
# epoch 64 | loss: 0.00063 | val_0_mse: 0.00011 |  0:00:44s
# epoch 65 | loss: 0.00063 | val_0_mse: 0.00011 |  0:00:45s
# epoch 66 | loss: 0.00063 | val_0_mse: 0.00011 |  0:00:45s
# epoch 67 | loss: 0.00062 | val_0_mse: 0.00011 |  0:00:46s
# epoch 68 | loss: 0.00062 | val_0_mse: 0.00011 |  0:00:47s
# epoch 69 | loss: 0.00062 | val_0_mse: 0.00011 |  0:00:47s
# epoch 70 | loss: 0.00061 | val_0_mse: 0.00011 |  0:00:48s
# epoch 71 | loss: 0.00062 | val_0_mse: 0.00011 |  0:00:49s
# epoch 72 | loss: 0.00062 | val_0_mse: 0.00011 |  0:00:49s
# epoch 73 | loss: 0.00061 | val_0_mse: 0.00012 |  0:00:50s
# epoch 74 | loss: 0.00061 | val_0_mse: 0.00011 |  0:00:51s
# epoch 75 | loss: 0.00061 | val_0_mse: 0.00011 |  0:00:51s
# epoch 76 | loss: 0.00061 | val_0_mse: 0.00011 |  0:00:52s
# epoch 77 | loss: 0.0006  | val_0_mse: 0.00011 |  0:00:52s
# epoch 78 | loss: 0.0006  | val_0_mse: 0.00011 |  0:00:53s
# epoch 79 | loss: 0.0006  | val_0_mse: 0.00011 |  0:00:54s
# epoch 80 | loss: 0.0006  | val_0_mse: 0.00012 |  0:00:54s
# epoch 81 | loss: 0.0006  | val_0_mse: 0.00011 |  0:00:55s
# epoch 82 | loss: 0.00059 | val_0_mse: 0.00012 |  0:00:56s
# epoch 83 | loss: 0.0006  | val_0_mse: 0.00011 |  0:00:56s
# epoch 84 | loss: 0.0006  | val_0_mse: 0.00011 |  0:00:57s
# epoch 85 | loss: 0.00059 | val_0_mse: 0.00011 |  0:00:58s
# epoch 86 | loss: 0.00058 | val_0_mse: 0.00012 |  0:00:58s
# epoch 87 | loss: 0.00058 | val_0_mse: 0.00011 |  0:00:59s
# epoch 88 | loss: 0.00058 | val_0_mse: 0.00012 |  0:01:00s
# epoch 89 | loss: 0.00058 | val_0_mse: 0.00011 |  0:01:00s
# epoch 90 | loss: 0.00057 | val_0_mse: 0.00011 |  0:01:01s
# epoch 91 | loss: 0.00057 | val_0_mse: 0.00012 |  0:01:02s
# epoch 92 | loss: 0.00057 | val_0_mse: 0.00011 |  0:01:02s
# epoch 93 | loss: 0.00056 | val_0_mse: 0.00011 |  0:01:03s
# epoch 94 | loss: 0.00056 | val_0_mse: 0.00011 |  0:01:04s
# epoch 95 | loss: 0.00055 | val_0_mse: 0.00012 |  0:01:04s
# epoch 96 | loss: 0.00058 | val_0_mse: 0.00011 |  0:01:05s
# epoch 97 | loss: 0.00056 | val_0_mse: 0.00011 |  0:01:05s
# epoch 98 | loss: 0.00055 | val_0_mse: 0.00011 |  0:01:06s
# epoch 99 | loss: 0.00055 | val_0_mse: 0.00011 |  0:01:07s
# Stop training because you reached max_epochs = 100 with best_epoch = 98 and best_val_0_mse = 0.00011
# Best weights from best epoch are automatically used!

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

Y_pred = reg_high.predict(X_test).flatten() 

print("MSE = {}".format(mean_squared_error(Y_test, Y_pred))) 
print("MAE = {}".format(mean_absolute_error(Y_test, Y_pred)))
# Out:
# MSE = 0.0001048256689187855
# MAE = 0.007808809547850269

# %%
plt.figure()
plt.figure(figsize=(12, 12))
plt.plot(Y_pred, label="predicted returns") 
plt.legend()

# %%
plt.figure()
plt.figure(figsize=(12, 12))
plt.plot(Y_test, label="actual returns") 
plt.legend()

# %% [markdown]
# # Train Low Model

# %%
input_columns = [] 
for col in train_df.columns:
    if col != 'high_delta' and col != 'years': 
        input_columns.append(col) 

X_train = train_df[input_columns].values 
Y_train = train_df['low_delta'].values 
Y_train = Y_train.reshape((-1,1))

X_val = val_df[input_columns].values
Y_val = val_df['low_delta'].values 
Y_val = Y_val.reshape((-1,1))

X_test = test_df[input_columns].values 
Y_test = test_df['low_delta'].values  
Y_test = Y_test.reshape((-1,1))

# %%
reg_low = TabNetRegressor() 

reg_low.fit(X_train, Y_train, 
            eval_set=[(X_val, Y_val)], 
            max_epochs=100, 
            patience=100)
# Out:
# Device used : cuda
# epoch 0  | loss: 0.37936 | val_0_mse: 0.49783 |  0:00:00s
# epoch 1  | loss: 0.05511 | val_0_mse: 0.01912 |  0:00:01s
# epoch 2  | loss: 0.01569 | val_0_mse: 0.00103 |  0:00:01s
# epoch 3  | loss: 0.00698 | val_0_mse: 0.00051 |  0:00:02s
# epoch 4  | loss: 0.00318 | val_0_mse: 0.00033 |  0:00:03s
# epoch 5  | loss: 0.00207 | val_0_mse: 0.00027 |  0:00:04s
# epoch 6  | loss: 0.00168 | val_0_mse: 0.00025 |  0:00:04s
# epoch 7  | loss: 0.0015  | val_0_mse: 0.00026 |  0:00:05s
# epoch 8  | loss: 0.00135 | val_0_mse: 0.00026 |  0:00:05s
# epoch 9  | loss: 0.00127 | val_0_mse: 0.00025 |  0:00:06s
# epoch 10 | loss: 0.00122 | val_0_mse: 0.00025 |  0:00:07s
# epoch 11 | loss: 0.00119 | val_0_mse: 0.00024 |  0:00:07s
# epoch 12 | loss: 0.00116 | val_0_mse: 0.00025 |  0:00:08s
# epoch 13 | loss: 0.00113 | val_0_mse: 0.00025 |  0:00:09s
# epoch 14 | loss: 0.00109 | val_0_mse: 0.00024 |  0:00:09s
# epoch 15 | loss: 0.00106 | val_0_mse: 0.00024 |  0:00:10s
# epoch 16 | loss: 0.00104 | val_0_mse: 0.00024 |  0:00:11s
# epoch 17 | loss: 0.00103 | val_0_mse: 0.00023 |  0:00:11s
# epoch 18 | loss: 0.00102 | val_0_mse: 0.00023 |  0:00:12s
# epoch 19 | loss: 0.00098 | val_0_mse: 0.00022 |  0:00:13s
# epoch 20 | loss: 0.00095 | val_0_mse: 0.00022 |  0:00:13s
# epoch 21 | loss: 0.00093 | val_0_mse: 0.00021 |  0:00:14s
# epoch 22 | loss: 0.00094 | val_0_mse: 0.00021 |  0:00:15s
# epoch 23 | loss: 0.00091 | val_0_mse: 0.0002  |  0:00:15s
# epoch 24 | loss: 0.00089 | val_0_mse: 0.0002  |  0:00:16s
# epoch 25 | loss: 0.00089 | val_0_mse: 0.00019 |  0:00:17s
# epoch 26 | loss: 0.00086 | val_0_mse: 0.00019 |  0:00:17s
# epoch 27 | loss: 0.00086 | val_0_mse: 0.00018 |  0:00:18s
# epoch 28 | loss: 0.00084 | val_0_mse: 0.00019 |  0:00:19s
# epoch 29 | loss: 0.00082 | val_0_mse: 0.00017 |  0:00:19s
# epoch 30 | loss: 0.00081 | val_0_mse: 0.00017 |  0:00:20s
# epoch 31 | loss: 0.00079 | val_0_mse: 0.00017 |  0:00:21s
# epoch 32 | loss: 0.00077 | val_0_mse: 0.00017 |  0:00:21s
# epoch 33 | loss: 0.00077 | val_0_mse: 0.00017 |  0:00:22s
# epoch 34 | loss: 0.00076 | val_0_mse: 0.00017 |  0:00:23s
# epoch 35 | loss: 0.00074 | val_0_mse: 0.00015 |  0:00:23s
# epoch 36 | loss: 0.00073 | val_0_mse: 0.00017 |  0:00:24s
# epoch 37 | loss: 0.00072 | val_0_mse: 0.00016 |  0:00:25s
# epoch 38 | loss: 0.00069 | val_0_mse: 0.00015 |  0:00:25s
# epoch 39 | loss: 0.00068 | val_0_mse: 0.00015 |  0:00:26s
# epoch 40 | loss: 0.00067 | val_0_mse: 0.00015 |  0:00:27s
# epoch 41 | loss: 0.00065 | val_0_mse: 0.00015 |  0:00:27s
# epoch 42 | loss: 0.00064 | val_0_mse: 0.00016 |  0:00:28s
# epoch 43 | loss: 0.00063 | val_0_mse: 0.00015 |  0:00:29s
# epoch 44 | loss: 0.00062 | val_0_mse: 0.00013 |  0:00:29s
# epoch 45 | loss: 0.00061 | val_0_mse: 0.00014 |  0:00:30s
# epoch 46 | loss: 0.0006  | val_0_mse: 0.00013 |  0:00:31s
# epoch 47 | loss: 0.00057 | val_0_mse: 0.00014 |  0:00:31s
# epoch 48 | loss: 0.00056 | val_0_mse: 0.00013 |  0:00:32s
# epoch 49 | loss: 0.00055 | val_0_mse: 0.00012 |  0:00:33s
# epoch 50 | loss: 0.00055 | val_0_mse: 0.00013 |  0:00:33s
# epoch 51 | loss: 0.00053 | val_0_mse: 0.00013 |  0:00:34s
# epoch 52 | loss: 0.00052 | val_0_mse: 0.00012 |  0:00:35s
# epoch 53 | loss: 0.00054 | val_0_mse: 0.00011 |  0:00:35s
# epoch 54 | loss: 0.00051 | val_0_mse: 0.0001  |  0:00:36s
# epoch 55 | loss: 0.0005  | val_0_mse: 0.00011 |  0:00:37s
# epoch 56 | loss: 0.00048 | val_0_mse: 0.0001  |  0:00:37s
# epoch 57 | loss: 0.00046 | val_0_mse: 0.00011 |  0:00:38s
# epoch 58 | loss: 0.00047 | val_0_mse: 0.00012 |  0:00:39s
# epoch 59 | loss: 0.00046 | val_0_mse: 0.0001  |  0:00:39s
# epoch 60 | loss: 0.00046 | val_0_mse: 0.0001  |  0:00:40s
# epoch 61 | loss: 0.00046 | val_0_mse: 8e-05   |  0:00:41s
# epoch 62 | loss: 0.00044 | val_0_mse: 9e-05   |  0:00:41s
# epoch 63 | loss: 0.00043 | val_0_mse: 8e-05   |  0:00:42s
# epoch 64 | loss: 0.00042 | val_0_mse: 9e-05   |  0:00:43s
# epoch 65 | loss: 0.00041 | val_0_mse: 9e-05   |  0:00:43s
# epoch 66 | loss: 0.00041 | val_0_mse: 8e-05   |  0:00:44s
# epoch 67 | loss: 0.00041 | val_0_mse: 8e-05   |  0:00:45s
# epoch 68 | loss: 0.00039 | val_0_mse: 7e-05   |  0:00:45s
# epoch 69 | loss: 0.00039 | val_0_mse: 7e-05   |  0:00:46s
# epoch 70 | loss: 0.00038 | val_0_mse: 6e-05   |  0:00:47s
# epoch 71 | loss: 0.00037 | val_0_mse: 6e-05   |  0:00:47s
# epoch 72 | loss: 0.00037 | val_0_mse: 7e-05   |  0:00:48s
# epoch 73 | loss: 0.00036 | val_0_mse: 8e-05   |  0:00:48s
# epoch 74 | loss: 0.00036 | val_0_mse: 5e-05   |  0:00:49s
# epoch 75 | loss: 0.00037 | val_0_mse: 7e-05   |  0:00:50s
# epoch 76 | loss: 0.00035 | val_0_mse: 4e-05   |  0:00:50s
# epoch 77 | loss: 0.00036 | val_0_mse: 6e-05   |  0:00:51s
# epoch 78 | loss: 0.00035 | val_0_mse: 5e-05   |  0:00:52s
# epoch 79 | loss: 0.00035 | val_0_mse: 6e-05   |  0:00:52s
# epoch 80 | loss: 0.00036 | val_0_mse: 5e-05   |  0:00:53s
# epoch 81 | loss: 0.00034 | val_0_mse: 5e-05   |  0:00:54s
# epoch 82 | loss: 0.00033 | val_0_mse: 5e-05   |  0:00:54s
# epoch 83 | loss: 0.00033 | val_0_mse: 4e-05   |  0:00:55s
# epoch 84 | loss: 0.00033 | val_0_mse: 4e-05   |  0:00:56s
# epoch 85 | loss: 0.00032 | val_0_mse: 4e-05   |  0:00:56s
# epoch 86 | loss: 0.00032 | val_0_mse: 5e-05   |  0:00:57s
# epoch 87 | loss: 0.00032 | val_0_mse: 5e-05   |  0:00:58s
# epoch 88 | loss: 0.00032 | val_0_mse: 3e-05   |  0:00:58s
# epoch 89 | loss: 0.00032 | val_0_mse: 4e-05   |  0:00:59s
# epoch 90 | loss: 0.00031 | val_0_mse: 4e-05   |  0:00:59s
# epoch 91 | loss: 0.0003  | val_0_mse: 5e-05   |  0:01:00s
# epoch 92 | loss: 0.0003  | val_0_mse: 4e-05   |  0:01:01s
# epoch 93 | loss: 0.00029 | val_0_mse: 4e-05   |  0:01:01s
# epoch 94 | loss: 0.0003  | val_0_mse: 4e-05   |  0:01:02s
# epoch 95 | loss: 0.0003  | val_0_mse: 4e-05   |  0:01:03s
# epoch 96 | loss: 0.0003  | val_0_mse: 5e-05   |  0:01:03s
# epoch 97 | loss: 0.0003  | val_0_mse: 4e-05   |  0:01:04s
# epoch 98 | loss: 0.00029 | val_0_mse: 3e-05   |  0:01:05s
# epoch 99 | loss: 0.00028 | val_0_mse: 3e-05   |  0:01:05s
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_mse = 3e-05
# Best weights from best epoch are automatically used!

# %%
Y_pred = reg_low.predict(X_test).flatten() 

print("MSE = {}".format(mean_squared_error(Y_test, Y_pred))) 
print("MAE = {}".format(mean_absolute_error(Y_test, Y_pred)))
# Out:
# MSE = 4.307122152635479e-05
# MAE = 0.004433137810416228

# %%
plt.figure()
plt.figure(figsize=(12, 12))
plt.plot(Y_pred, label="predicted returns") 
plt.legend()

# %%
plt.figure()
plt.figure(figsize=(12, 12))
plt.plot(Y_test, label="actual returns") 
plt.legend()
